# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Importing Dataset

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-211f1ccf-26f8-4169-941a-44924c365ae4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-211f1ccf-26f8-4169-941a-44924c365ae4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# - Dataset has 30 rows and 17 columns

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# - Except ERA i.e float type, all other features are of integer type.

# %% [markdown]
# # Checking for null values in the dataframe

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values present.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# # Checking Correlation

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="White",fmt=".2f")

# %% [markdown]
# - R (Runs) has 43 percent correlation with target column which is considered as a good +ve bond.
#
# - AB (At Bats) has -9 percent correlation with target column which is considered as a weak -ve bond.
#
# - H (Hit) has 4 percent correlation with target column which is considered as a weak +ve bond.
#
# - 2B (Doubles) has 43 percent correlation with target column which is considered as a good +ve bond.
#
# - 3b (Triples) has -25 percent correlation with target column which is considered as a good -ve bond.
#
# - HR (Home Runs) has 31 percent correlation with target column which is considered as a good +ve bond.
#
# - BB (Base on Balls) has 48 percent correlation with target column which is considered as a good +ve bond.
#
# - SO (Strike Out) has 11 percent correlation with target column which is considered as a weak +ve bond.
#
# - SB (Stolen Bases) has -16 percent correlation with target column which is considered as a weak -ve bond.
#
# - RA (Runs Allowed) has -81 percent correlation with target column which is considered as a very strong -ve bond.
#
# - ER (Earned Runs) has -81 percent correlation with target column which is considered as a very strong -ve bond.
#
# - ERA (Earned Runs Average) has -82 percent correlation with target column which is considered as a very strong -ve bond.
#
# - CG (Complete Games) has 8 percent correlation with target column which is considered as a weak +ve bond.
#
# - SHO (Shut Out) has 47 percent correlation with target column which is considered as a good +ve bond.
#
# - SV (Save) has 67 percent correlation with target column which is considered as a strong +ve bond.
#
# - E (Errors) has -9 percent correlation with target column which is considered as a weak -ve bond.

# %%
plt.figure(figsize=(15,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=14)
plt.ylabel('Target',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# - Max -ve correlation : ERA (Earned Runs Average)
# - Min -ve correlation : AB (At Bases) and E (Errors)
#
# - Max +ve correlation : SV (Saves)
# - Min +ve correlation : H (Hits)

# %% [markdown]
# # Visulaization

# %%
sns.countplot(df["W"])
print(df['W'].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# - In target column, 68 number of wins has highest count.

# %%
import matplotlib.pyplot as plt
sns.set()
fig, axes = plt.subplots(4, 4,figsize=(30, 20))
plt.subplots_adjust(bottom=0.00001)

sns.scatterplot(x=df["R"],y=df["W"],ax=axes[0,0])
axes[0,0].set_xlabel("Runs")

sns.scatterplot(x=df["AB"],y=df["W"],ax=axes[0,1])
axes[0,1].set_xlabel("At Bats")

sns.scatterplot(x=df["H"],y=df["W"],ax=axes[0,2])
axes[0,2].set_xlabel("Hits")

sns.scatterplot(x=df["2B"],y=df["W"],ax=axes[0,3])
axes[0,3].set_xlabel("Doubles")

sns.scatterplot(x=df["3B"],y=df["W"],ax=axes[1,0])
axes[1,0].set_xlabel("Triples")

sns.scatterplot(x=df["HR"],y=df["W"],ax=axes[1,1])
axes[1,1].set_xlabel("Home Runs")

sns.scatterplot(x=df["BB"],y=df["W"],ax=axes[1,2])
axes[1,2].set_xlabel("Walks")

sns.scatterplot(x=df["SO"],y=df["W"],ax=axes[1,3])
axes[1,3].set_xlabel("Strike Outs")

sns.scatterplot(x=df["SB"],y=df["W"],ax=axes[2,0])
axes[2,0].set_xlabel("Stolen Bases")

sns.scatterplot(x=df["RA"],y=df["W"],ax=axes[2,1])
axes[2,1].set_xlabel("Runs Allowed")

sns.scatterplot(x=df["ER"],y=df["W"],ax=axes[2,2])
axes[2,2].set_xlabel("Earned Runs")

sns.scatterplot(x=df["ERA"],y=df["W"],ax=axes[2,3])
axes[2,3].set_xlabel("Earned Runs Average")


sns.scatterplot(x=df["E"],y=df["W"],ax=axes[3,0])
axes[3,0].set_xlabel("Errors")

sns.scatterplot(x=df["CG"],y=df["W"],ax=axes[3,1])
axes[3,1].set_xlabel("Complete Game")

sns.scatterplot(x=df["SHO"],y=df["W"],ax=axes[3,2])
axes[3,2].set_xlabel("Shut Outs")

sns.scatterplot(x=df["SV"],y=df["W"],ax=axes[3,3])
axes[3,3].set_xlabel("Saves")
# Out:
# Text(0.5, 0, 'Saves')

# %% [markdown]
# - There is a non linear relationship between each input feature and target column W (Wins).

# %%
sns.pairplot(df)

# %% [markdown]
# # Describing Data

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# - There is huge gap between 75% and Max value which indicates presence of outlier in some of the features.
#
# - Data is widely spread in most of the features.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,7))
sns.heatmap(df.describe()[1:],annot=True,linewidths=0.1,linecolor="White",fmt=".2f")

# %% [markdown]
# W	(Wins)
#
# - mean	- 80.966667
# - std	- 10.453455
# - min	- 63.000000
# -max	- 100.000000
#
# R	(Runs)
# - mean - 688.233333
# -std	- 58.761754
# -min	- 573.000000
# -max	- 891.000000
#
# AB	(At Bats)
# - mean	-	5516.266667
# -std	- 	70.467372
# -min	- 	5385.000000
# -max	- 5649.000000
#
# H	(Hit)
# - mean	-	1403.533333
# -std	- 	57.140923
# -min	- 	1324.000000
# -max	- 1515.000000
#
# 2B	(Double)
# - mean	-	274.733333
# -std	-	18.095405
# -min	- 236.000000
# -max	- 308.000000
#
# 3B	(Triple)
# - mean	- 31.300000
# -std	-	10.452355
# -min	- 13.000000
# -max	- 49.000000
#
# HR	(Home Run)
# - mean	-	163.633333
# -std	-	31.823309
# -min	- 100.000000
# -max	- 232.000000
#
# BB	(Base on Balls)
# - mean	- 469.100000
# -std	-	57.053725
# -min	- 375.000000
# -max	- 570.000000
#
# SO	(Strike Out)
# - mean	- 1248.20000
# -std	-	103.75947
# -min	- 973.000000
# -max	- 1518.00000
#
# SB (Stolen Bases)
# - mean	-	83.500000
# -std	-	22.815225
# -min	- 44.000000
# -max	- 134.000000
#
# RA	(Runs Allowed)
# - mean	- 688.233333
# -std	-	72.108005
# -min	- 525.000000
# -max	- 844.000000
#
# ER	(Earned Runs)
# - mean	- 635.833333
# -std	-	70.140786
# -min	- 478.000000
# -max	- 799.000000
#
# ERA	(Earned Runs Average)
# - mean	-	3.956333
# -std	-	0.454089
# -min	- 2.940000
# -max	- 5.040000
#
# CG (Complete Games)
# - mean	-	3.466667
# -std	-	2.763473
# -min	- 0.0
# -max	- 11.000000
#
# SHO	(Shut Outs)
# - mean	-	11.300000
# -std	-	4.120177
# -min	- 4.000000
# -max	- 21.000000
#
# SV	(Saves)
# - mean	- 43.066667	94.333333
# -std	-	7.869335
# -min	- 28.000000
# -max	- 62.000000
#
# E (Erros)
# - mean	- 94.333333
# -std	-	13.958889
# -min	- 75.000000
# -max	- 126.000000

# %% [markdown]
# # Checking Outliers

# %%
import matplotlib.pyplot as plt
df.iloc[:,0:18].boxplot(figsize=(20,8))
plt.subplots_adjust(bottom=0.1)
plt.show()

# %% [markdown]
# - R(Runs), ERA(Earned Runs Average), SHO(Shut Outs), SV(Saves) and E(Errors) features have outlier.

# %%
new_df_cap = df.copy()

# %%
def remove_outliers(n):
    Q1 = np.percentile(df[n], 25, interpolation = 'midpoint')  
    Q3 = np.percentile(df[n], 75, interpolation = 'midpoint') 
    iqr = Q3 - Q1 
    percentile25 = df[n].quantile(0.25)
    percentile75 = df[n].quantile(0.75)
    upper_limit = percentile75 + 1.5 * iqr
    lower_limit = percentile25 - 1.5 * iqr
    df[df[n] > upper_limit]
    df[df[n] < lower_limit]
    
    new_df = df[df[n] < upper_limit]
    new_df.shape
    
    new_df_cap[n] = np.where(
    new_df_cap[n] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap[n] < lower_limit,
        lower_limit,
        new_df_cap[n] ) )
    
    sns.boxplot(new_df_cap[n])

# %%
remove_outliers("R")

# %%
remove_outliers("ERA")

# %%
remove_outliers("SHO")

# %%
remove_outliers("SV")

# %%
remove_outliers("E")

# %%
import matplotlib.pyplot as plt
new_df_cap.iloc[:,0:18].boxplot(figsize=(20,8))
plt.subplots_adjust(bottom=0.1)
plt.show()

# %% [markdown]
# # Separating feature and target data

# %%
x=new_df_cap.drop(["W"],axis=1)
x.head()
# Out:
#        R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG   SHO  \
# 0  724.0  5575  1497  300  42  139  383   973  104  641  601  3.73   2   8.0
# 1  696.0  5467  1349  277  44  156  439  1264   70  700  653  4.07   2  12.0
# 2  669.0  5439  1395  303  29  141  533  1157   86  640  584  3.67  11  10.0
# 3  622.0  5533  1381  260  27  136  404  1231   68  701  643  3.98   7   9.0
# 4  689.0  5605  1515  289  49  151  455  1259   83  803  746  4.64   7  12.0
#
#      SV      E
# 0  56.0   88.0
# 1  45.0   86.0
# 2  38.0   79.0
# 3  37.0  101.0
# 4  35.0   86.0

# %%
y=new_df_cap["W"]
y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %% [markdown]
# # Detecting Skewness

# %%
x.skew().sort_values()
# Out:
# 2B    -0.230650
# SO    -0.156065
# ERA   -0.014698
# RA     0.045734
# ER     0.058710
# 3B     0.129502
# BB     0.158498
# AB     0.183437
# SHO    0.218030
# R      0.235377
# SB     0.479893
# E      0.484667
# HR     0.516441
# SV     0.581064
# H      0.670254
# CG     0.736845
# dtype: float64

# %% [markdown]
# Keeping +/-0.5 as the range for skewness we can see following features contain skewness
# - HR (Home Runs)
# -SV (Saves)
# -H (Hits)
# -CG (Complete Games)

# %%
X=x

# %%
import matplotlib.pyplot as plt
sns.set()
fig, axes = plt.subplots(4,figsize=(10, 5))


sns.distplot(X["H"],ax=axes[0])
axes[0].set_ylabel("H")

sns.distplot(X["HR"],ax=axes[1])
axes[1].set_ylabel("HR")

sns.distplot(X["CG"],ax=axes[2])
axes[2].set_ylabel("CG")

sns.distplot(X["SV"],ax=axes[3])
axes[3].set_ylabel("SV")
# Out:
# Text(0, 0.5, 'SV')

# %% [markdown]
# All the columns displayed above are of discrete data type.

# %%
from sklearn.preprocessing import power_transform
list2=["HR","CG","SV","ERA"]     
for i in list2:
  X[i]=power_transform(X[i].values.reshape(-1,1))

# %%
a=np.cbrt(X["H"])
X["H"]=a

# %%
import matplotlib.pyplot as plt
sns.set()
fig, axes = plt.subplots(4,figsize=(10, 8))
plt.subplots_adjust(bottom=0.001)

sns.distplot(X["H"],ax=axes[0])
axes[0].set_ylabel("H")

sns.distplot(X["HR"],ax=axes[1])
axes[1].set_ylabel("HR")

sns.distplot(X["CG"],ax=axes[2])
axes[2].set_ylabel("CG")

sns.distplot(X["SV"],ax=axes[3])
axes[3].set_ylabel("SV")

axes[3].set_xlabel("W")
# Out:
# Text(0.5, 0, 'W')

# %% [markdown]
# After transformation
# - all the columns displayed above are of discrete data type.

# %%
a=np.sqrt(X["H"])
a.skew()
# Out:
# 0.6355943145469447

# %%
a=np.log(X["H"])
a.skew()
# Out:
# 0.628553626159119

# %%
a=np.cbrt(X["H"])
a.skew()
# Out:
# 0.6332514681503136

# %% [markdown]
# - After trying multiple method, it is observed that the skewness of feature H cannot be reduced below 0.62.
# - And looking at correlation matrix, we can observe that feature H (Hits) has a least contribution to the target variable, hence we decide to drop the column.

# %%
X=X.drop(["H"],axis=1)

# %%
X.skew().sort_values()
# Out:
# 2B    -0.230650
# SO    -0.156065
# CG    -0.059785
# ERA   -0.001246
# HR    -0.000065
# SV     0.001398
# RA     0.045734
# ER     0.058710
# 3B     0.129502
# BB     0.158498
# AB     0.183437
# SHO    0.218030
# R      0.235377
# SB     0.479893
# E      0.484667
# dtype: float64

# %% [markdown]
# # Detecting Collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(X)
# Out:
#    variables           VIF
# 0          R   1179.930694
# 1         AB  55299.833994
# 2         2B    832.612083
# 3         3B     29.943258
# 4         HR      6.245472
# 5         BB    254.181726
# 6         SO    407.184388
# 7         SB     24.006228
# 8         RA  15408.060436
# 9         ER  64749.520480
# 10       ERA    525.067909
# 11        CG      2.653854
# 12       SHO     32.600388
# 13        SV      3.574286
# 14         E    110.092075

# %% [markdown]
# - VIF>5 indicates collinearity.
# - We drop feature AB and R since it has very high collinearity and least contribution to target column.

# %%
X2=X.drop(["AB","R"],axis=1)
calc_vif(X2)
# Out:
#    variables           VIF
# 0         2B    536.051758
# 1         3B     27.500453
# 2         HR      2.449428
# 3         BB    234.300012
# 4         SO    332.697072
# 5         SB     23.776378
# 6         RA  15088.869979
# 7         ER  11322.738844
# 8        ERA     19.780767
# 9         CG      2.183048
# 10       SHO     31.024892
# 11        SV      2.924564
# 12         E    105.101606

# %% [markdown]
# # Traning and Testing

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split


mns=MinMaxScaler()
s=mns.fit_transform(X2)
xs=pd.DataFrame(data=s)
print(xs)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.888889  0.805556  0.388991  0.041026  0.000000  0.666667  0.363636
# 1   0.569444  0.861111  0.526013  0.328205  0.533945  0.288889  0.548589
# 2   0.930556  0.444444  0.405937  0.810256  0.337615  0.466667  0.360502
# 3   0.333333  0.388889  0.363121  0.148718  0.473394  0.266667  0.551724
# 4   0.736111  1.000000  0.487290  0.410256  0.524771  0.433333  0.871473
# 5   1.000000  0.111111  1.000000  1.000000  0.326606  0.488889  0.454545
# 6   0.500000  0.166667  0.891982  0.917949  0.466055  0.211111  0.542320
# 7   0.138889  0.194444  0.919894  0.220513  0.656881  0.000000  0.526646
# 8   0.583333  0.527778  0.607098  0.312821  0.618349  0.477778  0.366771
# 9   0.805556  0.555556  0.563541  0.528205  0.321101  0.300000  0.714734
# 10  0.597222  0.527778  0.642243  0.656410  0.477064  0.633333  0.652038
# 11  0.583333  0.361111  0.989617  0.569231  0.768807  0.855556  0.291536
# ...

# %% [markdown]
# #PCA

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(xs)

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,6)

fig, ax = plt.subplots()
a = np.arange(1, 14, step=1)
b = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(a, b, marker='o', linestyle='--', color='b')

plt.xlabel('No. of Components currently present in dataset')
plt.xticks(np.arange(0, 12, step=1))
plt.ylabel('Cumulative variance (%)')
plt.title('No. of components needed')

plt.axhline(y=0.97, color='r', linestyle='-')
plt.text(0.90, 0.90, '97% cut-off threshold', color = 'red', fontsize=15)
ax.grid(axis='x')
plt.show()

# %%
pca = PCA(n_components = 9)
pca.fit(xs)
x = pca.transform(xs)
x.shape
# Out:
# (30, 9)

# %% [markdown]
# #Training Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
lr=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i}, training accuracy: {r2_score(y_train,pred_train)}")
    print(f"At random state {i}, testing accuracy: {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, training accuracy: 0.8678497351543243
# At random state 0, testing accuracy: 0.39121019384116007
#
#
# At random state 1, training accuracy: 0.8810138192430729
# At random state 1, testing accuracy: 0.40405738623402143
#
#
# At random state 2, training accuracy: 0.857001483379205
# At random state 2, testing accuracy: 0.1540490204607361
#
#
# At random state 3, training accuracy: 0.8306346416347928
# At random state 3, testing accuracy: 0.7611568482854324
#
#
# At random state 4, training accuracy: 0.8085517077119148
# At random state 4, testing accuracy: 0.7677143668770383
#
#
# At random state 5, training accuracy: 0.8424875490104524
# At random state 5, testing accuracy: 0.7025809210159952
#
#
# At random state 6, training accuracy: 0.823469888983254
# At random state 6, testing accuracy: 0.7505367122936603
#
#
# At random state 7, training accuracy: 0.8552040905286712
# At random state 7, testing accuracy: 0.22782478024020048
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=99)
lr.fit(x_train,y_train) 
pred_train=lr.predict(x_train)
print("Testing Score:",r2_score(y_test,pred_test)*100)
# Out:
# Testing Score: 86.76489901996484

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print("Mean Absolute Error ",mean_absolute_error(y_test,pred_test))
print("Mean Sq. Error ",mean_squared_error(y_test,pred_test))
print("Root Mean Sq ",np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# Mean Absolute Error  3.5613783411282705
# Mean Sq. Error  17.929885411008737
# Root Mean Sq  4.234369541148804

# %% [markdown]
# # Cross validation

# %%
train_ac=r2_score(y_train,pred_train)
test_ac=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,5):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cv= {j} cv score is {cv_mean} and accuracy for training is {train_ac} and testing is {train_ac}")
    print("\n")
# Out:
# At cv= 2 cv score is -0.8378179951825145 and accuracy for training is 0.8089152377045933 and testing is 0.8089152377045933
#
#
# At cv= 3 cv score is 0.20714477431570108 and accuracy for training is 0.8089152377045933 and testing is 0.8089152377045933
#
#
# At cv= 4 cv score is 0.5747458419472845 and accuracy for training is 0.8089152377045933 and testing is 0.8089152377045933

# %% [markdown]
# - Cross Validation is best at cv=4

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual Wins")
plt.ylabel("Predicted Wins")
plt.title("Linear Regression")
plt.show()

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],
            'random_state': list(range(0,10)),
            'selection':['cyclic', 'random'],
            'fit_intercept': ['True','False']}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'fit_intercept': 'True', 'random_state': 1, 'selection': 'random'}

# %%
ls=Lasso(alpha=0.1,random_state=1,fit_intercept=True,selection='random')
ls.fit(x_train,y_train)
ls_score_train=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
print("Training Accuracy:",ls_score_train*100)
lss=r2_score(y_test,pred_ls)
print("Testing Accuracy:",lss*100)
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
print("Cross Validation:",cv_mean*100)
# Out:
# Training Accuracy: 81.83274938818013
# Testing Accuracy: 80.20332369554151
# Cross Validation: 5.434826705477256

# %% [markdown]
# #Model Selection

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.model_selection import cross_val_score

def model_selection(algorithm_instance,x_train,y_train,x_test,y_test):
    algorithm_instance.fit(x_train,y_train)
    model_pred_train=algorithm_instance.predict(x_train)
    model_pred_test=algorithm_instance.predict(x_test)
    print("Accuracy of training model :",r2_score(y_train,model_pred_train)*100)
    print("Accuracy of test data :",r2_score(y_test,model_pred_test)*100)
    cv_score=cross_val_score(algorithm_instance,x,y,cv=4)
    cv_mean=cv_score.mean()
    print("Cross Validation:",cv_mean*100)
    print("\nMean Absolute Error ",mean_absolute_error(y_test,model_pred_test))
    print("Mean Sq. Error ",mean_squared_error(y_test,model_pred_test))
    print("Root Mean Sq ",np.sqrt(mean_squared_error(y_test,model_pred_test)))
    print("\n")
    plt.figure(figsize=(8,6))
    plt.scatter(x=y_test,y=pred_test,color='r')
    plt.plot(y_test,y_test,color='b')
    plt.xlabel("Actual Wins")
    plt.ylabel("Predicted Wins")
    plt.title(algorithm_instance)
    plt.show()

# %% [markdown]
# # SVR

# %%
from sklearn import svm
k=svm.SVR()
model_selection(k,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 22.561296023837095
# Accuracy of test data : 14.167137655012429
# Cross Validation: -9.54881047320594
#
# Mean Absolute Error  8.610329413037517
# Mean Sq. Error  116.27968601569569
# Root Mean Sq  10.783305894562005

# %% [markdown]
# # DTR

# %%
from sklearn.tree import DecisionTreeRegressor
dtc = DecisionTreeRegressor()
model_selection(dtc,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 100.0
# Accuracy of test data : 11.297929054746792
# Cross Validation: 12.095729494858498
#
# Mean Absolute Error  8.833333333333334
# Mean Sq. Error  120.16666666666667
# Root Mean Sq  10.962055768270233

# %% [markdown]
# # XGBOOST

# %%
import xgboost as xg
xgb = xg.XGBRegressor()
model_selection(xgb,x_train,y_train,x_test,y_test)
# Out:
# [10:16:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Accuracy of training model : 99.99025140375234
# Accuracy of test data : 80.31545672738758
# [10:16:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:16:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Cross Validation: 43.473646413558264
#
# Mean Absolute Error  4.725594838460286
# Mean Sq. Error  26.667088205702992
# Root Mean Sq  5.164018610123611

# %% [markdown]
# # Ensemble Methods

# %% [markdown]
# # AdaBoostRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor

parameter={'loss':['linear', 'square', 'exponential'],
          'random_state' : range(0,100,10),
           'learning_rate':[0,1.0,2.0],
           'n_estimators':range(0,100,10)}

rf2=AdaBoostRegressor()
clf=GridSearchCV(rf2,parameter)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'learning_rate': 2.0, 'loss': 'linear', 'n_estimators': 40, 'random_state': 80}

# %%
rf2=AdaBoostRegressor(learning_rate= 2.0, loss= 'linear', n_estimators= 40, random_state= 80)
model_selection(rf2,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 96.94986990972244
# Accuracy of test data : 51.19167173210484
# Cross Validation: 41.519188419199004
#
# Mean Absolute Error  7.1350427350427355
# Mean Sq. Error  66.12172693403464
# Root Mean Sq  8.131526728360095

# %% [markdown]
# # BaggingRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingRegressor

parameter={'oob_score':['True','False'],
          'n_jobs':range(0,10),
           'random_state':range(0,100,10),
           'n_estimators':range(10,100,10)}

rf4=BaggingRegressor()
clf=GridSearchCV(rf4,parameter)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'n_estimators': 60, 'n_jobs': 1, 'oob_score': 'True', 'random_state': 80}

# %%
rf4=BaggingRegressor(oob_score= True, n_jobs= 1, n_estimators= 60, random_state= 80)
model_selection(rf4,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 94.62699830843637
# Accuracy of test data : 49.42092133141958
# Cross Validation: 54.061518206948136
#
# Mean Absolute Error  7.76388888888889
# Mean Sq. Error  68.52060185185188
# Root Mean Sq  8.277717188443434

# %% [markdown]
# # KNR

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor

parameter={
             'weights':['uniform', 'distance'],
             'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],
            'n_neighbors':range(0,10),
            'n_jobs':range(0,10)
         }

rf5=KNeighborsRegressor()
clf=GridSearchCV(rf5,parameter)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'algorithm': 'auto', 'n_jobs': 1, 'n_neighbors': 3, 'weights': 'uniform'}

# %%
rf5=KNeighborsRegressor(algorithm= 'auto', n_jobs=1, n_neighbors= 3, weights='uniform')
model_selection(rf5,x_train,y_train,x_test,y_test)
# Out:
# Accuracy of training model : 66.64045934291092
# Accuracy of test data : 64.91012234297042
# Cross Validation: 24.153184888952374
#
# Mean Absolute Error  6.61111111111111
# Mean Sq. Error  47.53703703703702
# Root Mean Sq  6.894710801551941

# %% [markdown]
# #Saving Model

# %%
import pickle
filename='lr.pk1'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# We selected Linear regression model since
# - it has best cross validation score among all the model and high accuracy.
# - it also has least Mean Absolute Error, Mean Sq. Error, Root Mean Sq

# %% [markdown]
# #Loading Saved Model

# %%
loaded_model=pickle.load(open('lr.pk1','rb'))
result=loaded_model.score(x_test,y_test)
print("\nModel Accuracy:",result*100)
pred_decision=lr.predict(x_test)
# Out:
# Model Accuracy: 86.76489901996484

# %% [markdown]
# # Testing Loaded Model

# %%
conc=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted Wins","Actual Wins"])
conc.astype(int)
# Out:
#                  0   1   2   3   4   5
# Predicted Wins  81  79  68  84  76  89
# Actual Wins     81  79  68  84  76  89
